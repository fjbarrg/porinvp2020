# %% [markdown]
# # Examen 1 - Portafolios de inversión - O2018. Tipo 2.
#
# <img style="float: right; margin: 0px 0px 15px 15px;" src="data:image/jpeg;base64,..." width="600px" height="400px" />
#
# **Resumen.**
# > Este examen pretende evaluar los conocimientos que hemos adquirido a lo largo de los dos primeros módulos.
#
# > El examen consta de dos partes.
# 1. La primera es meramente teórica, y los cálculos que puede llegar a involucrar son bastante sencillos. En esta parte, las preguntas son de selección múltiple con justificación, es decir, debes elegir la(s) respuesta(s) correcta(s) y decir porqué la seleccionaste.
# 2. La segunda parte es práctica, como lo que se ha venido haciendo en las tareas. En esta parte deberás importar un archivo donde se encuentran reportados los precios ajustados en el cierre de dos compañías en una base diaria, deberás caracterizar los rendimientos y con base en ello construir fronteras media-varianza bajo ciertas condiciones. Finalmente deberás concluir de los resultados.
#
# **Criterio de revisión.**
# > Primera parte: tiene un valor del 50% del examen. Cada pregunta tiene un valor del 10%, de los cuales 4% corresponde a la selección y el otro 6% corresponde a la justificación. Si la pregunta corresponde a un cálculo numérico, la justificación es en sí las operaciones resueltas para obtener el resultado en el notebook.
#
# > Segunda parte: tiene un valor del 50% del examen. Se te calificará de acuerdo a los resultados finales que reportes, basados en tu análisis.
#
# **Antes de comenzar.**
# > Por favor, nombrar este archivo *Examen1_ApellidoNombre*, sin acentos y sin espacios; por ejemplo, en mi caso el archivo se llamaría *Examen1_JimenezEsteban*. Resolver todos los puntos en dicho archivo y subir a moodle.
# ___

# %%
import pandas as pd
import pandas_datareader.data as web
import numpy as np
import scipy.optimize as opt
import matplotlib.pyplot as plt
import scipy.optimize as opt
# %matplotlib inline

# %% [markdown]
# ## I. Primera parte (50%)

# %% [markdown]
# **Pregunta 1.** Considere la siguiente distribución de rendimientos de los activos A, B y C:
#
# | Probabilidad     | Rendimiento A       | Rendimiento B         | Rendimiento C         |
# | ---------------- | ------------------  | -------------------   | ------------------    |
# | 50%              | 0.10                | 0.03                  | 0.08                  |
# | 30%              | 0.20                | 0.15                  | -0.13                 |
# | 20%              | -0.15               | -0.10                 | 0.02                  |
#
# ¿Cuál es el rendimiento esperado del activo C?
#
# A. 4.00%
#
# B. 5.00%
#
# C. 8.00%
#
# D. 0.50%

# %% [markdown]
# La respuesta correcta es (5%): __D__

# %%
tabla=pd.DataFrame(columns=['Prob','RendA','RendB','RendC'])
tabla['Prob']=[0.5,0.3,0.2]
tabla['RendA']=[0.1,0.2,-0.15]
tabla['RendB']=[0.03,0.15,-0.1]
tabla['RendC']=[0.08,-0.13,0.02]
tabla
# Out:
#    Prob  RendA  RendB  RendC
# 0   0.5   0.10   0.03   0.08
# 1   0.3   0.20   0.15  -0.13
# 2   0.2  -0.15  -0.10   0.02

# %%
# La justificación a esta pregunta son los cálculos necesarios para llegar al resultado (5%)
EA=(tabla['Prob']*tabla['RendA']).sum()
EB=(tabla['Prob']*tabla['RendB']).sum()
EC=(tabla['Prob']*tabla['RendC']).sum()
EC
# Out:
# 0.005000000000000001

# %% [markdown]
# **Pregunta 2.** Considere la siguiente distribución de rendimientos de los activos A, B y C:
#
# | Probabilidad     | Rendimiento A       | Rendimiento B         | Rendimiento C         |
# | ---------------- | ------------------  | -------------------   | ------------------    |
# | 50%              | 0.10                | 0.03                  | 0.08                  |
# | 30%              | 0.20                | 0.15                  | -0.13                 |
# | 20%              | -0.15               | -0.10                 | 0.02                  |
#
# ¿Cuál es la volatilidad del activo A?
#
# A. 9.12%
#
# B. 12.29%
#
# C. 6.63%
#
# D. 8.72%

# %% [markdown]
# La respuesta correcta es (5%): **B**

# %%
# La justificación a esta pregunta son los cálculos necesarios para llegar al resultado (5%)
sA=
sA
# Out:
#   File "<ipython-input-2-6911288b2f88>", line 2
#     sA=(tabla['RendA']-EA)**2 * tabla['Prob']).sum())**0.5
#                                              ^
# SyntaxError: invalid syntax

# %% [markdown]
# **Pregunta 3.** Considere la siguiente distribución de rendimientos de los activos A, B y C:
#
# | Probabilidad     | Rendimiento A       | Rendimiento B         | Rendimiento C         |
# | ---------------- | ------------------  | -------------------   | ------------------    |
# | 50%              | 0.10                | 0.03                  | 0.08                  |
# | 30%              | 0.20                | 0.15                  | -0.13                 |
# | 20%              | -0.15               | -0.10                 | 0.02                  |
#
#
# ¿Cuál es la el rendimiento esperado y la volatilidad de un portafolio compuesto 40% por el activo A, 40% por el activo B y 20% por el activo C?
#
# A. $E[r_P]$ = 9.40%, $\sigma_P$ = 7.25%
#
# B. $E[r_P]$ = 4.09%, $\sigma_P$ = 7.52%
#
# C. $E[r_P]$ = 4.90%, $\sigma_P$ = 7.52%
#
# D. $E[r_P]$ = 4.90%, $\sigma_P$ = 5.72%

# %% [markdown]
# La respuesta correcta es (5%): __C__

# %%
# La justificación a esta pregunta son los cálculos necesarios para llegar al resultado (5%)
tabla['PortABC']=0.4*tabla['RendA']+0.4*tabla['RendB']+0.2*tabla['RendC']
EABC=(tabla['Prob']*tabla['PortABC']).sum()
sABC=((tabla['PortABC'] - EABC)**2 * tabla['Prob']).sum()**0.5
EABC,sABC
# Out:
# (0.04900000000000001, 0.07518643494673757)

# %% [markdown]
# **Pregunta 4.** ¿Cuáles de los siguientes son ejemplos de riesgo de mercado (sistemático)?
#
#
# Seleccione todas las que apliquen.
#
# A. Recesión económica de EEUU.
#
# B. AMLO no logra vender el avión presidencial.
#
# C. Tercera guerra mundial.
#
# D. Cierta plaga ataca al aguacate Hass, disminuyendo su existencia a números muy bajos.

# %% [markdown]
# La respuesta correcta es (5%): __A, C__

# %% [markdown]
# Justificación (5%): **La recesión económica en una potencia mundial afecta a todo el mundo puesto que todo el mundo tiene algún tipo de activos en ellos o ellos tienen algún activo con el resto del mundo. Esto se demostró en la crisis de 2008.**
#
# **Si el desmoronamiento de una potencia hace la diferencia, una guerra mundial pondría al sistema financiero de cabeza, por lo que sin duda es un riesgo sistemático.**
#
# **Las otras dos opciones sin duda afectarían a muchos activos, sin embargo, es posible diversificarlos.**

# %% [markdown]
# **Pregunta 5.** La volatilidad de los rendimientos de un portafolio es siempre igual al promedio ponderado de las desviaciones estándar de los rendimientos de los activos individuales del portafolio.
#
# A. Verdadero.
#
# B. Falso.

# %% [markdown]
# La respuesta correcta es (5%): __B__

# %% [markdown]
# Justificación (5%): __Esta confusión es bastante común puesto que es posible obtener los rendimientos esperados de un portafolio de esta manera, sin embargo, la volatilidad funciona diferente. En el primer caso, es posible hacerlo así porque la fórmula constituye un operador lineal. En el caso de la volatilidad, al no ser un operador lineal nos arroja un resultado erróneo utilizando los promedios ponderados.__
#
# __Es necesario hacerlo mediante probabilidad o acomodando las ponderaciones en matrices para obtener los resultados correctos.__

# %% [markdown]
# ___
# ## II. Segunda parte (50%)

# %% [markdown]
# **Punto 1 (15%).** En los archivos `datamx.csv` y `dataus.csv` se encuentran reportados los **precios mensuales ajustados en el cierre** de los activos de Grupo Financiero Banorte, Grupo Financiero Inbursa, Grupo Aeroportuario del Pacífico y Herdez, y Microsoft, Apple, Coca-Cola y Nike, respectivamente, desde inicios del 2012 hasta el úlimo mes reportado.
#
# 1. Importar los **precios de mensuales** de las compañías <font color=red>americanas</font> en un **DataFrame indizado por fecha** (5%):
#  - Mostrar la gráfica de estos precios.
#  - Obtener un DataFrame con los **rendimientos porcentuales mensuales** para estos activos. Mostrar la gráfica de rendimientos.
#
# 2. Reportar en un **DataFrame el rendimiento esperado mensual y la volatilidad mensual** para cada uno de estos activos. Calcular las matrices de varianza-covarianza (**base mensual**) y de correlación (**base mensual**) para estos activos (5%).
#
# 3. De acuerdo a lo obtenido en el punto anterior, elija el par de activos que le ofrezca **la mejor oportunidad para diversificar**. Con estos activos seguirá trabajando en el resto del examen. **Escriba claramente qué activos seleccionó en una celda tipo markdown** (5%).

# %% [markdown]
# #### 1.

# %%
DatEx= pd.read_csv('DataExamen1/dataus.csv',index_col='Date')
DatEx
# Out:
#                   AAPL        MSFT         KO        NKE
# Date
# 2012-01-01   56.910862   24.440378  26.530993  23.635225
# 2012-02-01   67.627808   26.269470  27.446392  24.528452
# 2012-03-01   74.747902   26.875616  29.076834  24.646637
# 2012-04-01   72.806702   26.675678  30.203966  25.511318
# 2012-05-01   72.027489   24.318024  29.574728  24.669842
# 2012-06-01   72.809204   25.651567  30.944036  20.084307
# 2012-07-01   76.145485   24.712381  32.195293  21.358742
# 2012-08-01   82.937683   25.844444  29.804548  22.276237
# 2012-09-01   83.526672   25.120886  30.226908  21.795179
# 2012-10-01   74.539169   24.091064  29.830626  20.984547
# 2012-11-01   73.282082   22.470367  30.424356  22.385353
# 2012-12-01   66.936584   22.731602  29.284029  23.698893
# 2013-01-01   57.291748   23.361383  30.083775  24.931330
# 2013-02-01   55.519497   23.659254  31.279373  25.120451
# 2013-03-01   56.002468   24.550192  32.668850  27.324799
# 2013-04-01   56.017647   28.403057  34.443199  29.450216
# 2013-05-01   56.896927   29.947638  32.539192  28.551895
# 2013-06-01   50.498455   29.846550  32.636822  29.585991
# 2013-07-01   57.630104   27.513439  32.837833  29.232889
# 2013-08-01   62.047932   28.861458  31.281132  29.186430
# 2013-09-01   61.115425   28.960409  31.035341  33.861046
# 2013-10-01   67.005836   30.813950  32.655754  35.315434
# 2013-11-01   71.283600   33.180908  33.167427  36.891022
# 2013-12-01   72.338036   32.801250  34.330540  36.657948
# 2014-01-01   64.547462   33.178257  31.430189  34.065346
# 2014-02-01   67.853470   33.590370  31.745987  36.613815
# 2014-03-01   69.621613   36.209713  32.128262  34.643658
# 2014-04-01   76.541756   35.688511  34.166965  34.216827
# 2014-05-01   82.107712   36.165543  34.267494  36.074238
# 2014-06-01   84.850220   37.096779  35.482056  36.489243
# ...                ...         ...        ...        ...
# 2017-04-01  138.232330   65.481438  39.751255  53.809437
# 2017-05-01  146.998749   66.801399  41.888519  51.459343
# 2017-06-01  139.160446   66.308907  41.317348  57.295734
# 2017-07-01  143.711487   69.935555  42.576900  57.539742
# 2017-08-01  158.466263   71.926834  42.307541  51.459339
# 2017-09-01  149.504440   72.039268  41.805981  50.697506
# 2017-10-01  163.977585   80.443352  43.046753  53.767719
# 2017-11-01  166.703461   81.400795  42.850151  59.077011
# 2017-12-01  164.752060   83.141182  43.305294  61.159676
# 2018-01-01  162.999695   92.345612  44.919323  66.925179
# 2018-02-01  173.406830   91.140381  40.794559  65.757767
# 2018-03-01  164.006378   89.127190  40.992775  65.178970
# 2018-04-01  161.543045   91.324371  41.145153  67.294899
# 2018-05-01  182.667023   96.519478  40.945187  70.650284
# 2018-06-01  181.644363   96.712257  41.764091  78.404114
# 2018-07-01  186.727371  104.038513  44.797169  75.889862
# 2018-08-01  223.368286  110.168228  42.818138  81.109695
# 2018-09-01  222.290543  112.600616  44.374462  83.802170
# 2018-10-01  215.515686  105.157578  46.389294  74.227036
# 2018-11-01  175.851181  109.174454  48.830841  74.306168
# 2018-12-01  155.871613  100.430641  46.238560  73.554459
# 2019-01-01  164.468567  103.258560  47.000256  81.233330
# 2019-02-01  171.099075  110.773308  44.275742  85.052925
# 2019-03-01  188.505081  117.115051  45.760063  83.544930
# 2019-04-01  199.143539  129.686493  48.326653  87.360527
# 2019-05-01  173.738281  122.814903  48.395607  76.727669
# 2019-06-01  197.170853  133.515411  50.158848  82.237549
# 2019-07-01  212.233627  135.817734  52.248001  85.808327
# 2019-08-01  207.949905  137.402451  54.640507  84.282265
# 2019-09-01  223.970001  139.029999  54.044861  93.919998
#
# [93 rows x 4 columns]

# %%
DatEx.plot(figsize=(14,6), grid=True)
plt.title('Gráfica de los Activos')
plt.ylabel('Adj Close')
# Out:
# Text(0,0.5,'Adj Close')

# %%
ret= DatEx.pct_change().dropna()
ret.head()
# Out:
#                 AAPL      MSFT        KO       NKE
# Date
# 2012-02-01  0.188311  0.074839  0.034503  0.037792
# 2012-03-01  0.105284  0.023074  0.059405  0.004818
# 2012-04-01 -0.025970 -0.007439  0.038764  0.035083
# 2012-05-01 -0.010702 -0.088382 -0.020833 -0.032984
# 2012-06-01  0.010853  0.054838  0.046300 -0.185876

# %%
ret.plot(figsize=(14,6), grid=True)
plt.title('Rendimientos Porcentuales Mensuales')
# Out:
# Text(0.5,1,'Rendimientos Porcentuales Mensuales')

# %% [markdown]
# #### 2.

# %%
mens_ret_summ= pd.DataFrame(data={'Media':ret.mean(), 'Volatilidad':ret.std()}, index=ret.columns).T
mens_ret_summ
# Out:
#                  AAPL      MSFT        KO       NKE
# Media        0.017811  0.020692  0.008505  0.016839
# Volatilidad  0.075301  0.057852  0.038600  0.058976

# %%
#Matriz de Varianza-Covarianza
matvcz=ret.cov()
matvcz
# Out:
#           AAPL      MSFT        KO       NKE
# AAPL  0.005670  0.001608  0.000560  0.000788
# MSFT  0.001608  0.003347  0.000754  0.000686
# KO    0.000560  0.000754  0.001490  0.000254
# NKE   0.000788  0.000686  0.000254  0.003478

# %%
#Matriz de Correlación
matcorr=ret.corr()
matcorr
# Out:
#           AAPL      MSFT        KO       NKE
# AAPL  1.000000  0.369214  0.192702  0.177371
# MSFT  0.369214  1.000000  0.337857  0.201156
# KO    0.192702  0.337857  1.000000  0.111760
# NKE   0.177371  0.201156  0.111760  1.000000

# %% [markdown]
# #### 3.

# %% [markdown]
# Decidí trabajar con __Coca-Cola y Nike__, puesto que tienen la menor correlación entre ellos, por lo que es la mejor combinación para diversificar.

# %% [markdown]
# **Punto 2 (15%).** Usando los datos que obtuvo para los **activos que seleccionó** en el punto anterior:
#
# 1. Construya la frontera de mínima varianza que representa las posibles combinaciones de portafolios que se pueden crear con los activos que **seleccionó en el primer punto**. Reportar los **rendimientos esperados y las volatilidades de estos portafolios (base mensual) en un DataFrame** (8%).
#
# 2. Encontrar los pesos del portafolio de mínima varianza. Reportar el **rendimiento esperado mensual y la volatilidad mensual del portafolio de mínima varianza** (7%).

# %% [markdown]
# #### 1.

# %%
# Vector de w variando entre 0 y 1 con n pasos
N= 101
w= np.linspace(0,1,N)
# Rendimientos esperados individuales
# Activo1: Coca Cola, Activo2: Nike
E1= mens_ret_summ.loc['Media', 'KO']
E2= mens_ret_summ.loc['Media', 'NKE']
# Volatilidades individuales
s1= mens_ret_summ.loc['Volatilidad', 'KO']
s2= mens_ret_summ.loc['Volatilidad', 'NKE']
# Correlacion
r12= matcorr.loc['KO', 'NKE']
E1, E2, s1, s2, r12
# Out:
# (0.008504968654351342,
#  0.016839006403775017,
#  0.03860004315457088,
#  0.058975712527372624,
#  0.11175957369597901)

# %%
#Rendimientos esperados y las volatilidades de los posibles portafolios (base mensual)
portafolios2= pd.DataFrame(data={'w':w, 'Media': w*E1+(1-w)*E2, 'Volatilidad': ((w*s1)**2+((1-w)*s2)**2+2*w*(1-w)*s1*s2*r12)**0.5})
portafolios2
# Out:
#         w     Media  Volatilidad
# 0    0.00  0.016839     0.058976
# 1    0.01  0.016756     0.058430
# 2    0.02  0.016672     0.057888
# 3    0.03  0.016589     0.057347
# 4    0.04  0.016506     0.056810
# 5    0.05  0.016422     0.056275
# 6    0.06  0.016339     0.055744
# 7    0.07  0.016256     0.055215
# 8    0.08  0.016172     0.054689
# 9    0.09  0.016089     0.054166
# 10   0.10  0.016006     0.053647
# 11   0.11  0.015922     0.053131
# 12   0.12  0.015839     0.052618
# 13   0.13  0.015756     0.052109
# 14   0.14  0.015672     0.051603
# 15   0.15  0.015589     0.051101
# 16   0.16  0.015506     0.050603
# 17   0.17  0.015422     0.050109
# 18   0.18  0.015339     0.049619
# 19   0.19  0.015256     0.049134
# 20   0.20  0.015172     0.048652
# 21   0.21  0.015089     0.048175
# 22   0.22  0.015006     0.047702
# 23   0.23  0.014922     0.047235
# 24   0.24  0.014839     0.046772
# 25   0.25  0.014755     0.046314
# 26   0.26  0.014672     0.045861
# 27   0.27  0.014589     0.045414
# 28   0.28  0.014505     0.044972
# 29   0.29  0.014422     0.044535
# ..    ...       ...          ...
# 71   0.71  0.010922     0.033888
# 72   0.72  0.010838     0.033877
# 73   0.73  0.010755     0.033880
# 74   0.74  0.010672     0.033896
# 75   0.75  0.010588     0.033925
# 76   0.76  0.010505     0.033967
# 77   0.77  0.010422     0.034022
# 78   0.78  0.010338     0.034090
# 79   0.79  0.010255     0.034171
# 80   0.80  0.010172     0.034265
# 81   0.81  0.010088     0.034372
# 82   0.82  0.010005     0.034491
# 83   0.83  0.009922     0.034623
# 84   0.84  0.009838     0.034767
# 85   0.85  0.009755     0.034923
# 86   0.86  0.009672     0.035091
# 87   0.87  0.009588     0.035272
# 88   0.88  0.009505     0.035463
# 89   0.89  0.009422     0.035667
# 90   0.90  0.009338     0.035881
# 91   0.91  0.009255     0.036107
# 92   0.92  0.009172     0.036343
# 93   0.93  0.009088     0.036590
# 94   0.94  0.009005     0.036848
# 95   0.95  0.008922     0.037115
# 96   0.96  0.008838     0.037393
# 97   0.97  0.008755     0.037681
# 98   0.98  0.008672     0.037978
# 99   0.99  0.008588     0.038284
# 100  1.00  0.008505     0.038600
#
# [101 rows x 3 columns]

# %% [markdown]
# #### 2.

# %%
# Función objetivo
def varianza(w, s1, s2, r12):
    return(w * s1)**2 + ((1-w)*s2)**2+2*w*(1-w)*s1*s2*r12

# %%
# Dato inicial
w0=0.5
# Volatilidades individuales
#s1, s2
# Correlacion
#r12
# Cota de w
bnd=((0,1),)

# %%
# Solución
minvar=opt.minimize(fun=varianza, x0=w0, args=(s1, s2, r12), bounds=bnd)
minvar
# Out:
#       fun: array([0.00114763])
#  hess_inv: <1x1 LbfgsInvHessProduct with dtype=float64>
#       jac: array([8.67361738e-11])
#   message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 6
#       nit: 2
#    status: 0
#   success: True
#         x: array([0.72292593])

# %%
# Peso del portafolio de minima varianza
w_minvar2=minvar.x
w_minvar2, 1-w_minvar2
# Out:
# (array([0.72292593]), array([0.27707407]))

# %%
#Rendimiento esperado y volatilidad del portafolio de mínima varianza
E_minvar=w_minvar2*E1+(1-w_minvar2)*E2
s_minvar=varianza(w_minvar2,s1,s2,r12)**0.5
#s_minvar=minvar.fun**0.5
E_minvar,s_minvar
# Out:
# (array([0.01081411]), array([0.03387662]))

# %% [markdown]
# **Punto 3 (10%).** En este punto se usarán los mismos **activos que seleccionó** en el punto 1 con sus rendimientos esperados y volatilidades, solo que **el coeficiente de correlación entre sus rendimientos se supondrá de 0.5**.
#
# 1. Nuevamente, construya la frontera de mínima varianza para estos dos activos **con el nuevo supuesto de correlación**. Reportar **los rendimientos esperados y las volatilidades de estos portafolios en un DataFrame** (5%).
# 2. Encontrar los pesos del portafolio de mínima varianza. Reportar el **rendimiento esperado mensual y la volatilidad mensual del portafolio de mínima varianza** (5%).

# %% [markdown]
# #### 1.

# %%
# Vector de w variando entre 0 y 1 con n pasos
N= 101
w= np.linspace(0,1,N)
# Rendimientos esperados individuales
# Activo1: Coca Cola, Activo2: Nike
E1= mens_ret_summ.loc['Media', 'KO']
E2= mens_ret_summ.loc['Media', 'NKE']
# Volatilidades individuales
s1= mens_ret_summ.loc['Volatilidad', 'KO']
s2= mens_ret_summ.loc['Volatilidad', 'NKE']
# Correlacion
r12_3= 0.5
E1, E2, s1, s2, r12_3
# Out:
# (0.008504968654351342,
#  0.016839006403775017,
#  0.03860004315457088,
#  0.058975712527372624,
#  0.5)

# %%
#Rendimientos esperados y las volatilidades de los posibles portafolios (base mensual)
portafolios3= pd.DataFrame(data={'w':w, 'Media': w*E1+(1-w)*E2, 'Volatilidad': ((w*s1)**2+((1-w)*s2)**2+2*w*(1-w)*s1*s2*r12_3)**0.5})
portafolios3
# Out:
#         w     Media  Volatilidad
# 0    0.00  0.016839     0.058976
# 1    0.01  0.016756     0.058580
# 2    0.02  0.016672     0.058186
# 3    0.03  0.016589     0.057794
# 4    0.04  0.016506     0.057404
# 5    0.05  0.016422     0.057016
# 6    0.06  0.016339     0.056631
# 7    0.07  0.016256     0.056247
# 8    0.08  0.016172     0.055866
# 9    0.09  0.016089     0.055487
# 10   0.10  0.016006     0.055110
# 11   0.11  0.015922     0.054735
# 12   0.12  0.015839     0.054363
# 13   0.13  0.015756     0.053993
# 14   0.14  0.015672     0.053626
# 15   0.15  0.015589     0.053261
# 16   0.16  0.015506     0.052899
# 17   0.17  0.015422     0.052539
# 18   0.18  0.015339     0.052182
# 19   0.19  0.015256     0.051828
# 20   0.20  0.015172     0.051477
# 21   0.21  0.015089     0.051128
# 22   0.22  0.015006     0.050782
# 23   0.23  0.014922     0.050440
# 24   0.24  0.014839     0.050100
# 25   0.25  0.014755     0.049764
# 26   0.26  0.014672     0.049430
# 27   0.27  0.014589     0.049100
# 28   0.28  0.014505     0.048773
# 29   0.29  0.014422     0.048450
# ..    ...       ...          ...
# 71   0.71  0.010922     0.038889
# 72   0.72  0.010838     0.038782
# 73   0.73  0.010755     0.038681
# 74   0.74  0.010672     0.038588
# 75   0.75  0.010588     0.038501
# 76   0.76  0.010505     0.038421
# 77   0.77  0.010422     0.038348
# 78   0.78  0.010338     0.038282
# 79   0.79  0.010255     0.038222
# 80   0.80  0.010172     0.038170
# 81   0.81  0.010088     0.038124
# 82   0.82  0.010005     0.038086
# 83   0.83  0.009922     0.038055
# 84   0.84  0.009838     0.038030
# 85   0.85  0.009755     0.038013
# 86   0.86  0.009672     0.038003
# 87   0.87  0.009588     0.038000
# 88   0.88  0.009505     0.038004
# 89   0.89  0.009422     0.038015
# 90   0.90  0.009338     0.038033
# 91   0.91  0.009255     0.038059
# 92   0.92  0.009172     0.038091
# 93   0.93  0.009088     0.038130
# 94   0.94  0.009005     0.038177
# 95   0.95  0.008922     0.038230
# 96   0.96  0.008838     0.038290
# 97   0.97  0.008755     0.038357
# 98   0.98  0.008672     0.038431
# 99   0.99  0.008588     0.038512
# 100  1.00  0.008505     0.038600
#
# [101 rows x 3 columns]

# %% [markdown]
# #### 2.

# %%
# Función objetivo
def varianza_3(w, s1, s2, r12_3):
    return(w * s1)**2 + ((1-w)*s2)**2+2*w*(1-w)*s1*s2*r12_3

# %%
# Dato inicial
w0=0.5
# Volatilidades individuales
#s1, s2
# Correlacion
#r12
# Cota de w
bnd=((0,1),)

# %%
# Solución
minvar_3=opt.minimize(fun=varianza_3, x0=w0, args=(s1, s2, r12_3), bounds=bnd)
minvar_3
# Out:
#       fun: array([0.001444])
#  hess_inv: <1x1 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-7.74120351e-09])
#   message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 6
#       nit: 2
#    status: 0
#   success: True
#         x: array([0.86932294])

# %%
# Peso del portafolio de minima varianza
w_minvar2_3=minvar_3.x
w_minvar2_3, 1-w_minvar2_3
# Out:
# (array([0.86932294]), array([0.13067706]))

# %%
#Rendimiento esperado y volatilidad del portafolio de mínima varianza
E_minvar_3=w_minvar2_3*E1+(1-w_minvar2_3)*E2
s_minvar_3=varianza_3(w_minvar2_3,s1,s2,r12_3)**0.5
#s_minvar=minvar.fun**0.5
E_minvar_3,s_minvar_3
# Out:
# (array([0.00959404]), array([0.03800001]))

# %% [markdown]
# **Punto 4 (10%).**
#
# 1. Usando sus respuestas para los puntos 2 y 3, **grafique las dos fronteras encontradas en una sola gráfica**, además de los puntos correspondientes a los activos individuales, y de **los portafolios de mínima varianza para cada caso**, donde el eje $x$ es la volatilidad y el eje $y$ el rendimiento esperado. Asegúrese de etiquetar todo y poner distintos colores para diferenciar los distintos elementos en su gráfico (5%).
# 2. Concluya acerca de la gráfica de las dos fronteras de mínima varianza. ¿Cuál provee más diversificación?, ¿cómo se diferencian?, **¿son diferentes los pesos de los dos portafolios de varianza mínima en cada caso?**, **¿cómo puede explicar esta diferencia/similitud?** (5%).

# %% [markdown]
# #### 1.

# %%
# Graficar el portafolio de varianza mínima
# sobre el mismo gráfico realizado anteriormente
# Graficar el lugar geométrico de los portafolios en el
# espacio rendimiento esperado vs. volatilidad.
# Especificar también los puntos relativos a los casos
# extremos.
plt.figure(figsize=(8,6))
plt.plot(portafolios2['Volatilidad'],portafolios2['Media'],'k',lw=2, label='Portafolio 2')
plt.plot(portafolios3['Volatilidad'],portafolios3['Media'],'r',lw=2, label='Portafolio 3')
plt.plot(s1,E1, 'b*', ms=20, label='KO')
plt.plot(s2,E2, 'C5*', ms=20, label='NKE')
plt.plot(s_minvar,E_minvar,'C8*', ms=20, label='Port. min. var. Portafolio 2')
plt.plot(s1,E1, 'C1*', ms=20, label='KO')
plt.plot(s2,E2, 'C9*', ms=20, label='NKE')
plt.plot(s_minvar_3,E_minvar_3,'g*', ms=20, label='Port. min. var. Portafolio 3')
plt.xlabel('Volatilidad ($\sigma$)')
plt.ylabel('Rendimiento esperado ($E[r]$)')
plt.legend(loc='best')
plt.grid()

# %% [markdown]
# #### 2. Conclusiones

# %% [markdown]
# - Podemos observar que en los dos portafolios, las gráficas comienzan y terminan exactamente en el mismo punto. Esto se debe a que en la "w" siempre se considera primero (w=0) el portafolio con un solo activo y al último (w=1) con el otro.
# - Definitivamente, el portafolio que provee más diversificación es el "portafolio 2". Esto, en teoría, deber ser porque aumentamos la correlación entre ambos activos por casi 40% de un portafolio a otro. Sabemos que mientras menos correlación tengan la diversificación será mejor.
# - La diferencia entre los portafolios se puede observar tanto del lado de la volatilidad como del lado del rendimiento esperado. Mientras que el rendimiento esperado es de alrededor de 0.011 en el portafolio 2, en el 3 es de más o menos 0.09. Del lado de la volatilidad podemos ver que en el port 2 es de alrededor de 0.034, mientras que en el 3 oscila en el 0.038. En el caso general, el portafolio 2 está movido un poco a la izquierda y el 3 a la derecha.
# - El peso de los portafolios es diferente en cada caso. En ambos casos el mayor peso es para Coca Cola, sin embargo, el portafolio 2 apuesta alrededor de 15% más por Nike. Esta diferencia debe ser ocasionada por el grado de correlación entre los dos países, ya que al final de cuentas fue la única variable distinta entre los dos portafolios.

# %% [markdown]
# <script>
#   $(document).ready(function(){
#     $('div.prompt').hide();
#     $('div.back-to-top').hide();
#     $('nav#menubar').hide();
#     $('.breadcrumb').hide();
#     $('.hidden-print').hide();
#   });
# </script>
#
# <footer id="attribution" style="float:right; color:#808080; background:#fff;">
# Created with Jupyter by Esteban Jiménez Rodríguez.
# </footer>
